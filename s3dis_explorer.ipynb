# %% [markdown]
# <a href="https://colab.research.google.com/github/itberrios/3D/blob/main/s3dis_explorer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Stanford 3D Indoor Scene Dataset (S3DIS)**
#
# This notebook explores the [S3DIS](https://svl.stanford.edu/assets/papers/3D_Semantic_Parsing.pdf) dataset using [torch_geometric](https://pytorch-geometric.readthedocs.io/en/latest/index.html)

# %% [markdown]
# Install and import libraries

# %%
# !pip install open3d==0.16.0 # must be at least 0.16.0

# %%
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

# !pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git
# Out:
# 1.12.1+cu113

# %%
from IPython.display import clear_output
import numpy as np
import open3d as o3
# from open3d import JVisualizer # For Colab Visualization
# from open3d.web_visualizer import draw # for non Colab

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# [Open3D INFO] Resetting default logger to print to terminal.

# %% [markdown]
# Get Dataset

# %%
import torch_geometric
from torch_geometric.datasets import S3DIS

s3dis_train = S3DIS(root='temp', test_area=6, train=True)

# %%
s3dis_test = S3DIS(root='temp', test_area=6, train=False)

# split into valid and test sets
s3dis_valid = s3dis_test[:2000]
s3dis_test = s3dis_test[2000:]

# %%
print(f'Number of train samples: {len(s3dis_train)}')
print(f'Number of validation samples: {len(s3dis_valid)}')
print(f'Number of test samples: {len(s3dis_test)}')
s3dis_train[0]
# Out:
# Number of train samples: 20291
# Number of validation samples: 2000
# Number of test samples: 1294
# Data(x=[4096, 6], y=[4096], pos=[4096, 3])

# %% [markdown]
# The 'x' portion of the data set contains 0-1 normalized color and position values that can be fed into a model. The 'y' portion of the dataset contains truth labels that can be found in the original dataset. (TRUTH LABEL MAPPING TBD). The pos contains raw 3D positions and is similar to shapenet.
#
#
# Access normalized color x[:, :3], access normalized position x[:, 3:]

# %%
s3dis_train[0].x.max(axis=0)
# Out:
# torch.return_types.max(
# values=tensor([0.7137, 0.7176, 0.7059, 0.1873, 0.2232, 0.9940]),
# indices=tensor([1574, 1574, 1936, 2183, 4002,  178]))

# %%
s3dis_train[0].pos
# Out:
# tensor([[ 0.1530,  0.4780,  0.0510],
#         [-0.3110, -0.1510,  3.1610],
#         [ 0.3430, -0.0310,  3.1640],
#         ...,
#         [-0.0160,  0.1640,  3.1610],
#         [ 0.1510,  0.3780,  3.1580],
#         [-0.1110, -0.4910,  3.0480]])

# %%
np.unique(s3dis_train[332].y)
# Out:
# array([ 0,  1,  2, 12])

# %% [markdown]
# ## Display some stuff
#
# First we will get a color mapping for the truth labels

# %%
color_map = {
    0  : (255, 0, 0),
    1  : (0, 255, 0),
    2  : (0, 0, 255),
    3  : (255, 0, 255),
    4  : (0, 255, 255),
    5  : (255, 255, 0),
    6  : (128, 0, 128),
    7  : (128, 128, 0),
    8  : (0, 128, 128),
    9  : (128, 0, 255),
    10 : (255, 128, 0),
    11 : (0, 128, 255),
    12 : (128, 255, 128)
}

map_colors = lambda x : color_map[x]
v_map_colors = np.vectorize(map_colors)

# %%
IDX = 3220

# %%
pcd = o3.geometry.PointCloud()
pcd.points = o3.utility.Vector3dVector(s3dis_train[IDX].x[:, 3:].numpy())
# pcd.points = o3.utility.Vector3dVector(s3dis_train[IDX].pos.numpy())

pcd.colors = o3.utility.Vector3dVector(s3dis_train[IDX].x[:, :3].numpy())
# colors = np.vstack(v_map_colors(s3dis_train[IDX].y)).T
# pcd.colors = o3.utility.Vector3dVector(colors)

o3.visualization.draw_plotly([pcd])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="65b5d261-1ffc-464d-9e59-39a6345f145d" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65b5d261-1ffc-464d-9e59-39a6345f145d")) {                    Plotly.newPlot(                        "65b5d261-1ffc-464d-9e59-39a6345f145d",                        [{"marker":{"color":[[0.3960784375667572,0.40784314274787903,0.34117648005485535],[0.239215686917305,0.24313725531101227,0.21176470816135406],[0.7019608020782471,0.7058823704719543,0.6823529601097107],[0.5568627715110779,0.5411764979362488,0.4941176474094391],[0.2823529541492462,0.27843138575553894,0.26274511218070984],[0.9960784316062927,0.9882352948188782,0.9921568632125854],[0.3921568691730499,0.3607843220233917,0.3176470696926117],[0.4470588266849518,0.4470588266849518,0.40784314274787903],[0.8235294222831726,0.8549019694328308,0.8039215803146362],[0.32156863808631897,0.30980393290519714,0.33725491166114807],[0.5607843399047852,0.5372549295425415,0.4745098054409027],[0.2235294133424759,0.2078431397676468,0.21176470816135406],[0.250980406999588,0.2549019753932953,0.2235294133424759],[0.5843137502670288,0.5607843399047852,0.49803921580314636],[0.13333334028720856,0.14901961386203766,0.14509804546833038],[0.7372549176216125,0.729411780834198,0.6823529601097107],[0.4117647111415863,0.4274509847164154,0.42352941632270813],[0.5098039507865906,0.49803921580314636,0.42352941632270813],[0.4431372582912445,0.41960784792900085,0.364705890417099],[0.7411764860153198,0.7490196228027344,0.7450980544090271],[0.23529411852359772,0.23137255012989044,0.21568627655506134],[0.24705882370471954,0.250980406999588,0.22745098173618317],[0.4313725531101227,0.4117647111415863,0.33725491166114807],[0.4156862795352936,0.3960784375667572,0.32156863808631897],[0.8588235378265381,0.8627451062202454,0.8313725590705872],[0.41960784792900085,0.43921568989753723,0.4627451002597809],[0.3019607961177826,0.30588236451148987,0.2823529541492462],[0.5372549295425415,0.5098039507865906,0.4470588266849518],[0.545098066329956,0.5333333611488342,0.4745098054409027],[0.7372549176216125,0.7372549176216125,0.6980392336845398],[0.3960784375667572,0.3843137323856354,0.3490196168422699],[0.23137255012989044,0.23529411852359772,0.250980406999588],[0.4274509847164154,0.4313725531101227,0.3607843220233917],[0.4901960790157318,0.4745098054409027,0.4313725531101227],[0.1725490242242813,0.1725490242242813,0.1725490242242813],[0.5607843399047852,0.5333333611488342,0.47058823704719543],[0.5803921818733215,0.5568627715110779,0.4941176474094391],[0.11372549086809158,0.11764705926179886,0.09803921729326248],[0.7960784435272217,0.8156862854957581,0.800000011920929],[0.15294118225574493,0.14901961386203766,0.13333334028720856],[0.3921568691730499,0.3843137323856354,0.33725491166114807],[0.16078431904315948,0.16862745583057404,0.16470588743686676],[0.4274509847164154,0.4000000059604645,0.3607843220233917],[0.3764705955982208,0.3803921639919281,0.32549020648002625],[0.27450981736183167,0.22745098173618317,0.16470588743686676],[0.4274509847164154,0.41960784792900085,0.3294117748737335],[0.4156862795352936,0.4000000059604645,0.364705890417099],[0.239215686917305,0.21176470816135406,0.18039216101169586],[0.37254902720451355,0.35686275362968445,0.30980393290519714],[0.7607843279838562,0.7764706015586853,0.7803921699523926],[0.7450980544090271,0.3450980484485626,0.38823530077934265],[0.2823529541492462,0.27843138575553894,0.25882354378700256],[0.16078431904315948,0.16862745583057404,0.16470588743686676],[0.16078431904315948,0.16470588743686676,0.1725490242242813],[0.45098039507865906,0.48235294222831726,0.5254902243614197],[0.37254902720451355,0.33725491166114807,0.30980393290519714],[0.33725491166114807,0.32156863808631897,0.30980393290519714],[0.87058824 ...

# %% [markdown]
# #### Estimate Mesh for better visualation
#
# http://www.open3d.org/docs/latest/tutorial/Advanced/surface_reconstruction.html

# %%
pcd.estimate_normals()

# %%
radii = [0.005, 0.01, 0.02, 0.04]
rec_mesh = o3.geometry.TriangleMesh.create_from_point_cloud_ball_pivoting(
    pcd, o3.utility.DoubleVector(radii))
o3.visualization.draw_plotly([pcd, rec_mesh])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="da7f1491-5a5d-473a-94cd-f90bf65ecdb1" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("da7f1491-5a5d-473a-94cd-f90bf65ecdb1")) {                    Plotly.newPlot(                        "da7f1491-5a5d-473a-94cd-f90bf65ecdb1",                        [{"marker":{"color":[[0.3960784375667572,0.40784314274787903,0.34117648005485535],[0.239215686917305,0.24313725531101227,0.21176470816135406],[0.7019608020782471,0.7058823704719543,0.6823529601097107],[0.5568627715110779,0.5411764979362488,0.4941176474094391],[0.2823529541492462,0.27843138575553894,0.26274511218070984],[0.9960784316062927,0.9882352948188782,0.9921568632125854],[0.3921568691730499,0.3607843220233917,0.3176470696926117],[0.4470588266849518,0.4470588266849518,0.40784314274787903],[0.8235294222831726,0.8549019694328308,0.8039215803146362],[0.32156863808631897,0.30980393290519714,0.33725491166114807],[0.5607843399047852,0.5372549295425415,0.4745098054409027],[0.2235294133424759,0.2078431397676468,0.21176470816135406],[0.250980406999588,0.2549019753932953,0.2235294133424759],[0.5843137502670288,0.5607843399047852,0.49803921580314636],[0.13333334028720856,0.14901961386203766,0.14509804546833038],[0.7372549176216125,0.729411780834198,0.6823529601097107],[0.4117647111415863,0.4274509847164154,0.42352941632270813],[0.5098039507865906,0.49803921580314636,0.42352941632270813],[0.4431372582912445,0.41960784792900085,0.364705890417099],[0.7411764860153198,0.7490196228027344,0.7450980544090271],[0.23529411852359772,0.23137255012989044,0.21568627655506134],[0.24705882370471954,0.250980406999588,0.22745098173618317],[0.4313725531101227,0.4117647111415863,0.33725491166114807],[0.4156862795352936,0.3960784375667572,0.32156863808631897],[0.8588235378265381,0.8627451062202454,0.8313725590705872],[0.41960784792900085,0.43921568989753723,0.4627451002597809],[0.3019607961177826,0.30588236451148987,0.2823529541492462],[0.5372549295425415,0.5098039507865906,0.4470588266849518],[0.545098066329956,0.5333333611488342,0.4745098054409027],[0.7372549176216125,0.7372549176216125,0.6980392336845398],[0.3960784375667572,0.3843137323856354,0.3490196168422699],[0.23137255012989044,0.23529411852359772,0.250980406999588],[0.4274509847164154,0.4313725531101227,0.3607843220233917],[0.4901960790157318,0.4745098054409027,0.4313725531101227],[0.1725490242242813,0.1725490242242813,0.1725490242242813],[0.5607843399047852,0.5333333611488342,0.47058823704719543],[0.5803921818733215,0.5568627715110779,0.4941176474094391],[0.11372549086809158,0.11764705926179886,0.09803921729326248],[0.7960784435272217,0.8156862854957581,0.800000011920929],[0.15294118225574493,0.14901961386203766,0.13333334028720856],[0.3921568691730499,0.3843137323856354,0.33725491166114807],[0.16078431904315948,0.16862745583057404,0.16470588743686676],[0.4274509847164154,0.4000000059604645,0.3607843220233917],[0.3764705955982208,0.3803921639919281,0.32549020648002625],[0.27450981736183167,0.22745098173618317,0.16470588743686676],[0.4274509847164154,0.41960784792900085,0.3294117748737335],[0.4156862795352936,0.4000000059604645,0.364705890417099],[0.239215686917305,0.21176470816135406,0.18039216101169586],[0.37254902720451355,0.35686275362968445,0.30980393290519714],[0.7607843279838562,0.7764706015586853,0.7803921699523926],[0.7450980544090271,0.3450980484485626,0.38823530077934265],[0.2823529541492462,0.27843138575553894,0.25882354378700256],[0.16078431904315948,0.16862745583057404,0.16470588743686676],[0.16078431904315948,0.16470588743686676,0.1725490242242813],[0.45098039507865906,0.48235294222831726,0.5254902243614197],[0.37254902720451355,0.33725491166114807,0.30980393290519714],[0.33725491166114807,0.32156863808631897,0.30980393290519714],[0.87058824 ...

# %%
print('run Poisson surface reconstruction')
with o3.utility.VerbosityContextManager(
        o3.utility.VerbosityLevel.Debug) as cm:
    mesh, densities = o3.geometry.TriangleMesh.create_from_point_cloud_poisson(
        pcd, depth=3)
print(mesh)
o3.visualization.draw_plotly([mesh])
# Out:
# run Poisson surface reconstruction
# TriangleMesh with 599 points and 1125 triangles.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="df3dd87d-7284-4990-b5d0-86626c1099e8" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df3dd87d-7284-4990-b5d0-86626c1099e8")) {                    Plotly.newPlot(                        "df3dd87d-7284-4990-b5d0-86626c1099e8",                        [{"colorscale":[[0,"rgb(153, 153, 153)"],[1.0,"rgb(255,255,255)"]],"flatshading":true,"i":[20,32,32,21,22,34,23,35,24,36,36,25,37,26,27,40,28,30,0,31,31,1,41,2,41,41,56,46,42,56,48,5,48,57,6,58,43,9,10,45,11,47,57,49,59,57,49,51,51,50,50,58,15,60,52,52,52,51,54,54,54,61,18,55,19,43,89,69,69,69,33,71,34,72,35,74,74,36,76,37,38,80,40,63,79,43,44,82,45,83,48,84,73,73,73,84,92,85,85,85,85,92,85,53,54,87,55,79,62,94,69,95,71,97,72,99,99,74,76,103,103,78,80,96,108,79,109,81,113,113,111,111,70,116,84,110,77,117,85,118,86,119,87,108,122,96,98,125,100,127,127,102,133,133,133,147,133,147,137,135,135,139,137,137,139,136,140,149,140,140,109,143,113,111,143,147,116,148,150,145,141,150,136,145,118,149,122,152,152,123,125,154,154,127,157,157,156,157,176,135,178,177,178,139,179,155,207,207,206,185,187,187,185,161,189,162,191,163,193,193,166,195,168,196,164,198,198,165,198,200,208,200,208,200,170,194,160,202,172,203,173,204,174,175,196,183,211,211,184,186,215,217,215,188,234,217,221,234,221,209,242,242,211,213,245,215,247,247,217,250,220,254,303,241,305,244,274,303,277,305,280,282,306,280,248,278,249,286,252,271,288,288,291,253,293,309,293,309,295,295,296,311,258,260,312,260,314,307,261,307,298,318,299,299,299,264,301,299,263,301,265,302,266,353,274,355,277,282,358,280,319,319,319,322,319,358,326,327,361,326,355,331,329,334,335,335,334,286,324,337,288,291,337,289,342,365,283,344,298,346,368,349,346,299,352,368,352,349,352,302,377,375,375,408,379,408,410,408,379,384,382,382,410,384,413,387,413,330,387,416,333,387,416,392,412,420,414,422,419,425,394,394,394,422,381,394,424,427,396,401,401,429,338,338,427,430,403,403,403,404,405,341,343,341,432,345,345,405,433,405,347,348,347,407,434,388,418,348,434,351,418,375,438,377,439,440,439,439,440,470,442,442,442,441,442,471,444,443,443,443,444,472,392,445,472,396,398,447,448,448,450,401,450,450,452,452,453,404,453,455,405,455,457,480,459,461,406,407,406,459,388,459,481,436,483,438,489,512,482,491,491,485,513,491,495,495,495,442,497,499,497,443,514,499,494,501,501,447,516,484,517,484,448,518,516,519,452,520,453,452,455,505,506,519,507,520,507,457,507,508,508,509,523,509,510,510,502,458,528,553,528,528,483,527,533,533,535,533,535,537,537,485,540,540,491,542,493,495,545,545,497,532,546,546,556,504,537,505,537,548,506,548,549,557,550,559,508,509,508,551,551,551,551,543,502,529,564,564,563,569,577,571,580,573,582,575,534,577,536,539,539,539,538,582,585,582,561,597,560,598,565,564,565,63,30,65,64,64,88,65,67,41,67,67,67,90,70,90,70,73,75,96,63,64,100,65,102,66,104,104,67,68,107,110,73,112,75,93,124,94,126,128,126,95,146,128,131,146,131,101,132,132,103,106,122,121,158,159,159,159,159,181,162,162,162,129,163,131,166,166,132,134,151,164,136,165,138,169,169,140,169,171,171,170,180,160,176,172,177,178,174,175,175,175,145,164,151,184,184,152,186,153,188,154,156,192,192,157,233,182,235,185,187,237,189,239,239,210,233,212,235,236,216,237,218,219,239,219,195,209,222,196,224,198,197,224,226,225,199,226,200,226,194,229,202,230,230,203,231,204,205,222,241,210,244,212,246,214,248,216,218,252,219,240,253,222,254,257,257,223,257,256,267,259,259,259,259,258,267,228,268,251,221,262,262,262,262,265,264,264,263,265,231,232,253,271,240,273,272,242,273,304,276,304,276,276,247,281,279,279,281,310,285,313,287,292,312,292,290,290,294,317,316,297,297,293,293,320,271,272,323,325,325,325,354,325,330,330,328,354,330,357,333,333,333,338,338,338,341,343,364,362,367,363,369,345,345,345,345,348,365,371,36 ...
